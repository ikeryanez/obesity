# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df = pd.read_csv('../../data/obesity_red.csv')

# %%
# Graficar las variables numéricas
numeric_vars = df.select_dtypes(include=['int64', 'float64'])
sns.pairplot(numeric_vars)
plt.show()

# Graficar las variables categóricas
categorical_vars = df.select_dtypes(include=['object', 'category'])
for column in categorical_vars.columns:
    sns.countplot(x=column, data=df)
    plt.show()
# Out:
#       gender  age  height  weight history favc  fcvc  ncp       caec  ch2o  \
# 0     Female   21   162.0    64.0     yes   no  2.00  3.0  Sometimes  2.00
# 1       Male   23   180.0    77.0     yes   no  2.00  3.0  Sometimes  2.00
# 2       Male   27   180.0    87.0      no   no  3.00  3.0  Sometimes  2.00
# 3       Male   22   178.0    89.8      no   no  2.00  1.0  Sometimes  2.00
# 4       Male   29   162.0    53.0      no  yes  2.00  3.0  Sometimes  2.00
# ...      ...  ...     ...     ...     ...  ...   ...  ...        ...   ...
# 2131    Male   30   191.0   129.0     yes  yes  2.10  3.0  Sometimes  1.01
# 2132    Male   31   187.0   127.0     yes  yes  2.73  3.0  Sometimes  1.48
# 2133    Male   30   190.0   129.0     yes  yes  2.22  3.0  Sometimes  1.59
# 2134    Male   31   184.0   125.0     yes  yes  2.49  3.0  Sometimes  1.66
# 2135    Male   31   184.0   125.0     yes  yes  2.15  3.0  Sometimes  1.49
#
#      scc   faf        calc                 mtrans           nobeyesdad
# 0     no  0.00          no  Public_Transportation        Normal_Weight
# 1     no  2.00  Frequently  Public_Transportation        Normal_Weight
# 2     no  2.00  Frequently                Walking   Overweight_Level_I
# 3     no  0.00   Sometimes  Public_Transportation  Overweight_Level_II
# 4     no  0.00   Sometimes             Automobile        Normal_Weight
# ...   ..   ...         ...                    ...                  ...
# 2131  no  0.98   Sometimes  Public_Transportation      Obesity_Type_II
# 2132  no  1.48   Sometimes  Public_Transportation      Obesity_Type_II
# 2133  no  1.39   Sometimes  Public_Transportation      Obesity_Type_II
# 2134  no  0.99   Sometimes  Public_Transportation      Obesity_Type_II
# 2135  no  0.88   Sometimes  Public_Transportation      Obesity_Type_II
#
# [2136 rows x 15 columns]
